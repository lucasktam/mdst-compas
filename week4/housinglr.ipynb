# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.metrics import r2_score
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # EDA
#
# Load in your data first.

# %% [markdown]
# Print the head, shape, datatypes, and some basic statistics.

# %% [markdown]
# Use the sns.pairplot() function to map scatterplots of each variable to each other variable to find which variables are correlated with each other.
#
# There is one column that we can't use for this function. Why? Drop this column from the pairplot without dropping it from the original dataframe.

# %% [markdown]
# Use sns.jointplot() on any variable pair you'd like, which is a more straightforward way of generating these scatterplots

# %% [markdown]
# There is a column that needs to be cleaned. Which one is it?

# %% [markdown]
# Clean this column.

# %% [markdown]
# To further understand correlations between variable pairs, you can create a correlation heatmap between variables using seaborn.

# %%
# Create subplots
f, ax = plt.subplots(figsize=(20, 20))

# Drop 'ocean_proximity'
corr = housing.drop('ocean_proximity', axis=1).corr()

# Draw heatmap
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool), cmap=sns.diverging_palette(260, 295, as_cmap=True),
            square=True, ax=ax, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Creating a linear regression model

# %% [markdown]
# Single variable linear regression models take in an X and Y where X is the independent variable and Y is the dependent variable.
#
# We saw that 'households' and 'total_bedrooms' is strongly correlated when we ran sns.pairplot(). (Why?)
#
# Assign X to 'households' and Y to 'total_bedrooms'.
#
# Hint: You'll have to put X and Y into a specific shape. X needs to be a 2d array with dimensions (n_elements, n_features) where n_features = 1 because it's just one column. Y needs to be a 1d numpy array with dimensions (n_elements,). Use .shape() on each variable to verify. There are multiple ways to do this.

# %%
X =
Y =
# Out:
# (20640,)

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Print out the coefficients, intercept, and R2 score of your model.

# %%
# Out:
# [0.88826046]
# 22.686948149600425
# 0.9493896744364482

# %% [markdown]
# Print the .corr() of X and Y. What is the relationship between the r2 score and correlation?

# %%
# Out:
# array([[1.        , 0.97436629],
#        [0.97436629, 1.        ]])

# %% [markdown]
# Find the mean error, mean absolute error, and root mean squared error of these two variables.

# %% [markdown]
# Plot the regression line using matplotlib. Replace the xlabel, ylabel, and title.

# %% [markdown]
# Now try using sns.regplot or a different version of sns.jointplot to plot regression line.

# %% [markdown]
# Based on your model, what would be the total bedrooms of an area with 500 total households?

# %% [markdown]
# Plot residuals using a scatterplot.

# %% [markdown]
# Plot residuals using a histogram.

# %% [markdown]
# ## Making your own simple regression model
#
# What variable is the highest predictor of housing price? Run a linear regression model of this and find all relevant information.

# %% [markdown]
# # Multivariate Linear Regression Model
#
# Create a multivariate linear regression model which predicts 'households' based on 'population', 'total_bedrooms', 'total_rooms'. This is similar to a single variable linear regression model.
#
# It has a single intercept, but individual coefficients for each predictor.

# %% [markdown]
# #\#4fun
#
# Run this code and see what it does, then give it a title.

# %%
sns.set(rc={'figure.figsize': [20, 15]}, font_scale=1.2)
ax = sns.scatterplot(data=housing, x='longitude', y='latitude', hue='median_house_value', palette='cool', alpha=0.3);
ax.set_title("");

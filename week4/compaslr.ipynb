# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.metrics import r2_score
from google.colab import drive

drive.mount('/content/drive')

# %% [markdown]
# Load in your dataset

# %% [markdown]
# Clean data:
#
# Filter the columns to only include ['age', 'c_charge_degree', 'race', 'score_text', 'sex', 'priors_count', 'days_b_screening_arrest', 'decile_score', 'is_recid', 'two_year_recid', 'c_jail_in', 'c_jail_out']
#
# *   If the charge or arrest date of a defendants Compas scored crime was not within 30 days from when the person was compas scored, we assume that because of data quality reasons, that we do not have the right offense. (If days_b_screening_arrest > 30 OR if days_b_screening_arrest < 30, remove these rows from the dataset).
# *   the recidivist flag -- is_recid -- is -1 if we could not find a compas case at all. Remove these rows.
#
# *   ordinary traffic offenses -- those with a c_charge_degree of 'O' -- that will not result in Jail time are to be removed (only two of them).

# %% [markdown]
# Create a column named 'length_of_stay' that is the length a defendant stayed in jail.

# %% [markdown]
# Create a correlation heatmap.
#
# Note that the correlation heatmap only works on numerical values, and only makes sense for certain numerical values.
#
# How can you find which ones are numerical?
# What is a way to find out which ones make sense?
# Then filter the correlation heatmap and display it.

# %% [markdown]
# # Linear regression model

# %% [markdown]
# Create a linear regression model that predicts 'length_of_stay' based on one variable. How good is your model, and why? Output all the information we did for the housing dataset.

# %% [markdown]
# Try intrapolating the 'length_of_stay' of a fictitious defendant by plugging in numbers into your model.

# %% [markdown]
# Create a linear regression model that predicts the COMPAS score based on two or more variables. How good is your model, and why? Output all the information we did for the housing dataset.

# %% [markdown]
# Try intrapolating the 'length_of_stay' of a fictitious defendant by plugging in numbers into your new model.
